# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from retrying import retry
import time

start_time = time.time()


baseurl = 'http://ly75dbzixy7hlp663j32xo4dtoiikm6bxb53jvivqkpo6jwppptx3sad.onion'

def get_tor_session():
    session = requests.session()
    session.proxies = {'http': 'socks5h://127.0.0.1:9050',
                       'https': 'socks5h://127.0.0.1:9050'}
    return session

@retry(wait_exponential_multiplier=1000, wait_exponential_max=10000)
def get_page_content(session, link):
    return session.get(link)

session = get_tor_session()

print("Getting ...", baseurl)
req = session.get(baseurl)
print("got past r")
soup = BeautifulSoup(req.content, 'lxml')
print("got past SOUP")
productlist = soup.find_all('div', class_='image')

productlinks = []

for item in productlist:
    for link in item.find_all('a', href=True):
        productlinks.append(link['href'])

print(len(productlinks))

end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")

# %%
start_time = time.time()

productlink = productlinks[:5]

#link='http://ly75dbzixy7hlp663j32xo4dtoiikm6bxb53jvivqkpo6jwppptx3sad.onion/venusmarketplace/product/digital/apple-iphone-14-pro-max-1tb-apple-us-original'
productlist = []
vendorlist = []
V = []
for link in productlinks :
    r = get_page_content(session, link)
    soup = BeautifulSoup(r.content, 'lxml')

    name = soup.find('h1').text.strip()
    price = soup.find('span', class_='price-new').text.strip()
    tds = soup.find_all('td')
    li = soup.find_all('li')

    for i, td in enumerate(tds):
        if td.text == 'Vendor Name':
            vname = tds[i + 1].text
        if td.text == 'Total Sales':
            tsales = tds[i + 1].text
        if td.text == 'Member Since':
            doj = tds[i + 1].text

    for i, li in enumerate(li):
        if 'Product:' in li.text :
            cat = li.text.split(': ')[1]

    product = {
        'Product Name': name,
        'Price' : price,
        'Vendor Name' : vname,
        'Category' : cat
    }
    print(product)

    productlist.append(product)
    print('Saving: ', product['Product Name'])

    Vendors = {
        'Vendor Name' : vname,
        'DOJ' : doj,
        'Total Sales' : tsales
    }

    if vname not in V:
        V.append(vname)
        vendorlist.append(Vendors)
        print('Saving: ', Vendors['Vendor Name'])


df1 = pd.DataFrame(productlist)
df2 = pd.DataFrame(vendorlist)

pd.set_option('display.max_columns', None)
pd.set_option('display.width', 1000)

print(df1.head())
print('\n')
print(df2.head())

df1.to_csv('df1F.csv', index=False)  # Setting index=False to exclude the index from the CSV file
df1.to_csv('df1.csv')  # Setting index=False to exclude the index from the CSV file
df2.to_csv('df2F.csv', index=False)
df2.to_csv('df2.csv')

df1.to_excel('df1F.xlsx', index=False)
df1.to_excel('df1.xlsx' )
df2.to_excel('df2F.xlsx', index=False)
df2.to_excel('df2.xlsx' )

end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")
# Out:
# {'Product Name': '3 Gram Cocaine Powder High Quality 100% Pure (Best)', 'Price': '$120.00', 'Vendor Name': 'FlexxCocaine', 'Category': 'Cocaine'}
# Saving:  3 Gram Cocaine Powder High Quality 100% Pure (Best)
# Saving:  FlexxCocaine
# {'Product Name': '10 Gram Cocaine Powder High Quality 100% Pure (Best)', 'Price': '$320.00', 'Vendor Name': 'FlexxCocaine', 'Category': 'Cocaine'}
# Saving:  10 Gram Cocaine Powder High Quality 100% Pure (Best)
# {'Product Name': '20 Gram Cocaine Powder High Quality 100% Pure (Best)', 'Price': '$560.00', 'Vendor Name': 'FlexxCocaine', 'Category': 'Cocaine'}
# Saving:  20 Gram Cocaine Powder High Quality 100% Pure (Best)
# {'Product Name': '5 Gram Fishscale Cocaine', 'Price': '$150.00', 'Vendor Name': 'hardcoke', 'Category': 'Cocaine'}
# Saving:  5 Gram Fishscale Cocaine
# Saving:  hardcoke
# {'Product Name': '3 Gram Ultraclean 100% Pure Cocaine', 'Price': '$100.00', 'Vendor Name': 'DAGO37', 'Category': 'Cocaine'}
# Saving:  3 Gram Ultraclean 100% Pure Cocaine
# Saving:  DAGO37
# {'Product Name': '3 Gram Colombian Cocaine High Quality', 'Price': '$130.00', 'Vendor Name': 'Bulls', 'Category': 'Cocaine'}
# Saving:  3 Gram Colombian Cocaine High Quality
# Saving:  Bulls
# {'Product Name': '3 Gram Fishscale Cocaine AAA Quality', 'Price': '$80.00', 'Vendor Name': 'for4dream', 'Category': 'Cocaine'}
# Saving:  3 Gram Fishscale Cocaine AAA Quality
# Saving:  for4dream
# {'Product Name': 'Crack Cocaine Pure Uncut – 5GR', 'Price': '$160.00', 'Vendor Name': 'SpliceCoke', 'Category': 'Cocaine'}
# Saving:  Crack Cocaine Pure Uncut – 5GR
# Saving:  SpliceCoke
# {'Product Name': 'Bolivian Brick Cocaine Pure (High Quality) – 5GR', 'Price': '$170.00', 'Vendor Name': 'SpliceCoke', 'Category': 'Cocaine'}
# Saving:  Bolivian Brick Cocaine Pure (High Quality) – 5GR
# {'Product Name': 'Peruvian Cocaine 92% Pure – 5GR (High Quality)', 'Price': '$145.00', 'Vendor Name': 'SpliceCoke', 'Category': 'Cocaine'}
# Saving:  Peruvian Cocaine 92% Pure – 5GR (High Quality)
# {'Product Name': 'Cheap Cocaine Clearance – 3.5GR', 'Price': '$95.00', 'Vendor Name': 'SpliceCoke', 'Category': 'Cocaine'}
# Saving:  Cheap Cocaine Clearance – 3.5GR
# {'Product Name': 'Columbian Cocaine 91% Pure – 20GR', 'Price': '$370.00', 'Vendor Name': 'ColumbianCokeCO', 'Category': 'Cocaine'}
# Saving:  Columbian Cocaine 91% Pure – 20GR
# Saving:  ColumbianCokeCO
# {'Product Name': '3gr - Fish Scale Cocaine', 'Price': '$65.00', 'Vendor Name': 'Plamorica', 'Category': 'Cocaine'}
# Saving:  3gr - Fish Scale Cocaine
# Saving:  Plamorica
# {'Product Name': '5 Gram - MDMA (Crystal)', 'Price': '$130.00', 'Vendor Name': 'trailblazer', 'Category': 'MDMA'}
# Saving:  5 Gram - MDMA (Crystal)
# Saving:  trailblazer
# {'Product Name': '5 Gram - Dutch MDMA', 'Price': '$150.00', 'Vendor Name': 'trailblazer', 'Category': 'MDMA'}
# Saving:  5 Gram - Dutch MDMA
# {'Product Name': '3 Gram - Cola Dutch MDMA', 'Price': '$85.00', 'Vendor Name': 'trailblazer', 'Category': 'MDMA'}
# Saving:  3 Gram - Cola Dutch MDMA
# {'Product Name': '10 Gram - MDMA Molly (High Quality)', 'Price': '$160.00', 'Vendor Name': 'trailblazer', 'Category': 'MDMA'}
# Saving:  10 Gram - MDMA Molly (High Quality)
# {'Product Name': '5 Gram - Black Molly MDMA', 'Price': '$120.00', 'Vendor Name': 'trailblazer', 'Category': 'MDMA'}
# Saving:  5 Gram - Black Molly MDMA
# {'Product Name': '10 Gram - Dutch MDMA %87', 'Price': '$190.00', 'Vendor Name': 'MASTOK', 'Category': 'MDMA'}
# Saving:  10 Gram - Dutch MDMA %87
# Saving:  MASTOK
# {'Product Name': '50 Pills - Ecstasy/XTC - 220mg', 'Price': '$75.00', 'Vendor Name': 'Adis1990', 'Category': 'Ecstasy'}
# Saving:  50 Pills - Ecstasy/XTC - 220mg
# Saving:  Adis1990
# {'Product Name': '30 Pills Superman Ecstasy - XTC - MDMA - High Quality', 'Price': '$100.00', 'Vendor Name': 'T4ZZ', 'Category': 'Ecstasy'}
# Saving:  30 Pills Superman Ecstasy - XTC - MDMA - High Quality
# Saving:  T4ZZ
# {'Product Name': '30 Pills Gold Ecstasy - XTC - MDMA - High Quality', 'Price': '$100.00', 'Vendor Name': 'T4ZZ', 'Category': 'Ecstasy'}
# Saving:  30 Pills Gold Ecstasy - XTC - MDMA - High Quality
# {'Product Name': '30 Pills Mixed Ecstasy - XTC - MDMA - High Quality', 'Price': '$110.00', 'Vendor Name': 'T4ZZ', 'Category': 'Ecstasy'}
# Saving:  30 Pills Mixed Ecstasy - XTC - MDMA - High Quality
# {'Product Name': '30 Pills Dragon Ecstasy - XTC - MDMA - High Quality', 'Price': '$80.00', 'Vendor Name': 'T4ZZ', 'Category': 'Ecstasy'}
# Saving:  30 Pills Dragon Ecstasy - XTC - MDMA - High Quality
# {'Product Name': '100 Mixed Ecstasy - XTC - MDMA - High Quality', 'Price': '$250.00', 'Vendor Name': 'T4ZZ', 'Category': 'Ecstasy'}
# Saving:  100 Mixed Ecstasy - XTC - MDMA - High Quality
# {'Product Name': '10 Pills Mixed Ecstasy - XTC - MDMA - High Quality', 'Price': '$45.00', 'Vendor Name': 'T4ZZ', 'Category': 'Ecstasy'}
# Saving:  10 Pills Mixed Ecstasy - XTC - MDMA - High Quality
# {'Product Name': '100 Pills Dolphins Ecstasy - XTC - MDMA - High Quality', 'Price': '$220.00', 'Vendor Name': 'T4ZZ', 'Category': 'Ecstasy'}
# Saving:  100 Pills Dolphins Ecstasy - XTC - MDMA - High Quality
# {'Product Name': '30 Pills Special Ecstasy - XTC - MDMA', 'Price': '$70.00', 'Vendor Name': 'T4ZZ', 'Category': 'Ecstasy'}
# Saving:  30 Pills Special Ecstasy - XTC - MDMA
# {'Product Name': '100 Tabs LSD High Quality', 'Price': '$250.00', 'Vendor Name': 'D1BODE', 'Category': 'LSD'}
# Saving:  100 Tabs LSD High Quality
# Saving:  D1BODE
# {'Product Name': 'x50 LSD (Acid / LSD Tabs) 250ug', 'Price': '$140.00', 'Vendor Name': 'xarthe33', 'Category': 'LSD'}
# Saving:  x50 LSD (Acid / LSD Tabs) 250ug
# Saving:  xarthe33
# {'Product Name': '30 Tabs LSD 200ug', 'Price': '$90.00', 'Vendor Name': 'predator', 'Category': 'LSD'}
# Saving:  30 Tabs LSD 200ug
# Saving:  predator
# {'Product Name': '1 Gram - DMT (Pure 100%)', 'Price': '$80.00', 'Vendor Name': 'dmtdex', 'Category': 'DMT'}
# Saving:  1 Gram - DMT (Pure 100%)
# Saving:  dmtdex
# {'Product Name': '1 Gram Pure Crystalline N,N DMT - AAA Quality 99.7%', 'Price': '$50.00', 'Vendor Name': 'urieL', 'Category': 'DMT'}
# Saving:  1 Gram Pure Crystalline N,N DMT - AAA Quality 99.7%
# Saving:  urieL
# {'Product Name': '5 Gram - Crystal Meth', 'Price': '$110.00', 'Vendor Name': 'kite', 'Category': 'Meth'}
# Saving:  5 Gram - Crystal Meth
# Saving:  kite
# {'Product Name': '10 Gram - Crystal Meth', 'Price': '$180.00', 'Vendor Name': 'kite', 'Category': 'Meth'}
# Saving:  10 Gram - Crystal Meth
# {'Product Name': '50 Gram - Crystal Meth (High Quality)', 'Price': '$750.00', 'Vendor Name': 'kite', 'Category': 'Meth'}
# Saving:  50 Gram - Crystal Meth (High Quality)
# {'Product Name': '5 Gram - Crystal Meth (Ice)', 'Price': '$70.00', 'Vendor Name': 'NexuS', 'Category': 'Meth'}
# Saving:  5 Gram - Crystal Meth (Ice)
# Saving:  NexuS
# {'Product Name': '8.5 Gram - Crystal Meth AAA+ Quality', 'Price': '$100.00', 'Vendor Name': 'BigHiLL15', 'Category': 'Meth'}
# Saving:  8.5 Gram - Crystal Meth AAA+ Quality
# Saving:  BigHiLL15
# {'Product Name': '50gr Crystal Meth – Methamphetamine (90%+ Purity)', 'Price': '$360.00', 'Vendor Name': 'brokenchemist', 'Category': 'Meth'}
# Saving:  50gr Crystal Meth – Methamphetamine (90%+ Purity)
# Saving:  brokenchemist
# {'Product Name': '28gr - Crystal Meth (Clean)', 'Price': '$110.00', 'Vendor Name': 'brokenchemist', 'Category': 'Meth'}
# Saving:  28gr - Crystal Meth (Clean)
# {'Product Name': '10gr Crystal Meth Package', 'Price': '$60.00', 'Vendor Name': 'brokenchemist', 'Category': 'Meth'}
# Saving:  10gr Crystal Meth Package
# {'Product Name': 'Fentanyl Powder 10 Gram', 'Price': '$160.00', 'Vendor Name': 'CapitalPharmacy', 'Category': 'Fentanyl'}
# Saving:  Fentanyl Powder 10 Gram
# Saving:  CapitalPharmacy
# {'Product Name': '10 Gram Carfentanil/Fentanly Powder 98% Pure', 'Price': '$120.00', 'Vendor Name': 'CapitalPharmacy', 'Category': 'Fentanyl'}
# Saving:  10 Gram Carfentanil/Fentanly Powder 98% Pure
# {'Product Name': '180 ML - GHB', 'Price': '$110.00', 'Vendor Name': 'CapitalPharmacy', 'Category': 'GHB'}
# Saving:  180 ML - GHB
# {'Product Name': '500 Gram- Potassium Cyanide Technical', 'Price': '$250.00', 'Vendor Name': 'CapitalPharmacy', 'Category': 'Potassium Cyanide'}
# Saving:  500 Gram- Potassium Cyanide Technical
# {'Product Name': '250 Gram - Potassium Cyanide', 'Price': '$180.00', 'Vendor Name': 'CapitalPharmacy', 'Category': 'Potassium Cyanide'}
# Saving:  250 Gram - Potassium Cyanide
# {'Product Name': '28 Gram Sour Diesel', 'Price': '$80.00', 'Vendor Name': 'DarkWeed', 'Category': 'Weed'}
# Saving:  28 Gram Sour Diesel
# Saving:  DarkWeed
# {'Product Name': '10 Gram Sour Diesel, Gorilla Glue, Girl Scout', 'Price': '$115.00', 'Vendor Name': 'DarkWeed', 'Category': 'Weed'}
# Saving:  10 Gram Sour Diesel, Gorilla Glue, Girl Scout
# {'Product Name': '14 Grams (TOP QUALITY) CA Flowers', 'Price': '$60.00', 'Vendor Name': 'DarkWeed', 'Category': 'Weed'}
# Saving:  14 Grams (TOP QUALITY) CA Flowers
# {'Product Name': '10 Gram - Birthday Cake / Wedding Cake', 'Price': '$50.00', 'Vendor Name': 'razzy', 'Category': 'Weed'}
# Saving:  10 Gram - Birthday Cake / Wedding Cake
# Saving:  razzy
# {'Product Name': '20 Grams of Top Quality Moroccan Hash', 'Price': '$160.00', 'Vendor Name': 'DarkWeed', 'Category': 'Hash'}
# Saving:  20 Grams of Top Quality Moroccan Hash
# {'Product Name': '20 Gram Hashish Ketama Top A+++ Cream Hash', 'Price': '$130.00', 'Vendor Name': 'KUSHBANANA', 'Category': 'Hash'}
# Saving:  20 Gram Hashish Ketama Top A+++ Cream Hash
# Saving:  KUSHBANANA
# {'Product Name': '5 Gram Afghan Cream Hash', 'Price': '$55.00', 'Vendor Name': 'DarkWeed', 'Category': 'Hash'}
# Saving:  5 Gram Afghan Cream Hash
# {'Product Name': '5 Gram Super Hash Super Concentrated', 'Price': '$45.00', 'Vendor Name': 'DarkWeed', 'Category': 'Hash'}
# Saving:  5 Gram Super Hash Super Concentrated
